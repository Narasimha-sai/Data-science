# %%
 #Fetching the Data
import pandas as pd
data=pd.read_csv("BMI_Data.csv")
data_dataframe=pd.DataFrame(data)
data_dataframe
# Out:
#      Gender  Weight(in Kg)  Height(in m)        BMI            Index
# 0         0             96          1.74  31.708284          Obesity
# 1         0             87          1.89  24.355421           Normal
# 2         1            110          1.85  32.140248          Obesity
# 3         1            104          1.95  27.350427       Overweight
# 4         0             61          1.49  27.476240       Overweight
# 5         0            104          1.89  29.114526       Overweight
# 6         0             92          1.47  42.574853  Extreme Obesity
# 7         0            111          1.54  46.803846  Extreme Obesity
# 8         0             90          1.74  29.726516       Overweight
# 9         1            103          1.69  36.063163          Obesity
# 10        0             81          1.95  21.301775           Normal
# 11        1             80          1.59  31.644318          Obesity
# 12        1            101          1.92  27.398003       Overweight
# ...
